# %%
# importing required modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Downloading the DataFrame

# %%
df = pd.read_csv('dataset.csv')

# %%
df
# Out:
#                 verifiedby                     country  class  \
# 0           La Silla Vacía                    Colombia  FALSE
# 1               Newtral.es                       Spain  FALSE
# 2            FactCrescendo                       India  False
# 3      France 24 Observers                      France  False
# 4             Agência Lupa                      Brazil  False
# ...                    ...                         ...    ...
# 6897                Misbar   Middle East, North Africa  False
# 6898                 Teyit                      Turkey  False
# 6899           LeadStories               United States  FALSE
# 6900             Full Fact              United Kingdom  FALSE
# 6901               Rappler                 Philippines  False
#
#                                                   title published_date  \
# 0      The coronavirus is an amplified bacteria rela...    2020/06/17
# 1      A law allows people to go for a run during th...    2020/04/09
# ...

# %% [markdown]
# ## Preprocessing and Exploratory Data Analysis

# %%
# creating a copy of the orignal dataframe
new_df = df.copy()

# %%
new_df
# Out:
#                 verifiedby                     country  class  \
# 0           La Silla Vacía                    Colombia  FALSE
# 1               Newtral.es                       Spain  FALSE
# 2            FactCrescendo                       India  False
# 3      France 24 Observers                      France  False
# 4             Agência Lupa                      Brazil  False
# ...                    ...                         ...    ...
# 6897                Misbar   Middle East, North Africa  False
# 6898                 Teyit                      Turkey  False
# 6899           LeadStories               United States  FALSE
# 6900             Full Fact              United Kingdom  FALSE
# 6901               Rappler                 Philippines  False
#
#                                                   title published_date  \
# 0      The coronavirus is an amplified bacteria rela...    2020/06/17
# 1      A law allows people to go for a run during th...    2020/04/09
# ...

# %%
new_df.head()
# Out:
#              verifiedby    country  class  \
# 0        La Silla Vacía   Colombia  FALSE
# 1            Newtral.es      Spain  FALSE
# 2         FactCrescendo      India  False
# 3   France 24 Observers     France  False
# 4          Agência Lupa     Brazil  False
#
#                                                title published_date  \
# 0   The coronavirus is an amplified bacteria rela...    2020/06/17
# 1   A law allows people to go for a run during th...    2020/04/09
# 2   Chinese converting to Islam after realizing t...    2020/02/20
# 3   Bat market and bat meat are being sold in Wuhan.    2020/01/27
# 4   You can self-diagnose COVID-19 by holding you...    2020/03/16
#
#     country1 country2 country3 country4  \
# 0   Colombia      NaN      NaN      NaN
# 1      Spain      NaN      NaN      NaN
# 2      India      NaN      NaN      NaN
# 3     France      NaN      NaN      NaN
# 4     Brazil      NaN      NaN      NaN
#
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6902 entries, 0 to 6901
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   verifiedby      6902 non-null   object
#  1   country         6730 non-null   object
#  2   class           6900 non-null   object
#  3   title           6902 non-null   object
#  4   published_date  6902 non-null   object
#  5   country1        6730 non-null   object
#  6   country2        559 non-null    object
#  7   country3        101 non-null    object
#  8   country4        29 non-null     object
#  9   article_source  6895 non-null   object
#  10  ref_source      6902 non-null   object
#  11  source_title    6448 non-null   object
#  12  content_text    6127 non-null   object
#  13  category        172 non-null    object
#  14  lang            6560 non-null   object
# dtypes: object(15)
# memory usage: 809.0+ KB

# %%
new_df.describe()
# Out:
#        verifiedby country  class  \
# count        6902    6730   6900
# unique         91     388     51
# top           AFP   India  False
# freq          694    1178   2877
#
#                                                     title published_date  \
# count                                                6902           6902
# unique                                               6719            241
# top     Does Trump Own Stock in a Company CDC Uses for...    2020/03/17
# freq                                                    4            143
#
#        country1       country2        country3 country4  \
# count      6730            559             101       29
# unique      106             92              46       22
# top       India   North Africa   United States    Spain
# freq       1185            137               9        3
#
#                                            article_source ref_source  \
# count                                                6895       6902
# ...

# %%
new_df.describe().T
# Out:
#                count unique  \
# verifiedby      6902     91
# country         6730    388
# class           6900     51
# title           6902   6719
# published_date  6902    241
# country1        6730    106
# country2         559     92
# country3         101     46
# country4          29     22
# article_source  6895   6805
# ref_source      6902      2
# source_title    6448   5960
# content_text    6127   5857
# category         172     14
# lang            6560     30
#
#                                                               top  freq
# verifiedby                                                    AFP   694
# country                                                     India  1178
# class                                                       False  2877
# title           Does Trump Own Stock in a Company CDC Uses for...     4
# published_date                                        2020/03/17    143
# ...

# %%
new_df.shape
# Out:
# (6902, 15)

# %%
new_df['category'].value_counts()
# Out:
# US Government Response          28
# Trump and the Pandemic II       19
# Conspiracy Theories             16
# Origins and Spread              15
# Memes and Misinformation II     12
# Prevention and Treatments II    12
# Entertainment & Media           11
# Prevention and Treatments       10
# Business and Industry           10
# Viral Videos                     9
# International Response           9
# Trump and the Pandemic           8
# Prophecies and Predictions       7
# Memes and Misinformation         6
# Name: category, dtype: int64

# %%
new_df.drop('article_source', axis = 1, inplace = True)

# %%
new_df.head()
# Out:
#              verifiedby    country  class  \
# 0        La Silla Vacía   Colombia  FALSE
# 1            Newtral.es      Spain  FALSE
# 2         FactCrescendo      India  False
# 3   France 24 Observers     France  False
# 4          Agência Lupa     Brazil  False
#
#                                                title published_date  \
# 0   The coronavirus is an amplified bacteria rela...    2020/06/17
# 1   A law allows people to go for a run during th...    2020/04/09
# 2   Chinese converting to Islam after realizing t...    2020/02/20
# 3   Bat market and bat meat are being sold in Wuhan.    2020/01/27
# 4   You can self-diagnose COVID-19 by holding you...    2020/03/16
#
#     country1 country2 country3 country4 ref_source  \
# 0   Colombia      NaN      NaN      NaN    poynter
# 1      Spain      NaN      NaN      NaN    poynter
# 2      India      NaN      NaN      NaN    poynter
# 3     France      NaN      NaN      NaN    poynter
# ...

# %%
new_df['lang'].value_counts()
# Out:
# en    2750
# es    1321
# tl     530
# pt     481
# fr     408
# it     158
# ar      88
# de      85
# te      83
# uk      81
# mk      75
# id      67
# ml      66
# ta      56
# lt      54
# pl      49
# nl      41
# bn      41
# da      36
# lv      19
# ur      17
# pa      16
# et      15
# th       8
# ne       5
# sv       5
# tr       2
# ca       1
# fi       1
# sk       1
# Name: lang, dtype: int64

# %%
# selecting rows and columns with 'en' (english) as language
new_df1 = new_df[new_df['lang']=='en']

# %%
new_df1
# Out:
#           verifiedby         country        class  \
# 2      FactCrescendo           India        False
# 5         VERA Files     Philippines   MISLEADING
# 7          GhanaFact           Ghana  Mostly True
# 8         PolitiFact   United States        FALSE
# 9        AfricaCheck           Kenya        False
# ...              ...             ...          ...
# 6888             AFP        Thailand        FALSE
# 6892          snopes             NaN        False
# 6894             AFP        Malaysia        FALSE
# 6899     LeadStories   United States        FALSE
# 6901         Rappler     Philippines        False
#
#                                                   title       published_date  \
# 2      Chinese converting to Islam after realizing t...          2020/02/20
# 5      Captions on a reuploaded video about the U.S....          2020/05/09
# 7      Ghana has 307 ambulances with mobile ventilat...          2020/04/03
# ...

# %%
# looking for null values
new_df1.isnull().sum()
# Out:
# verifiedby           0
# country            172
# class                0
# title                0
# published_date       0
# country1           172
# country2          2631
# country3          2726
# country4          2748
# ref_source           0
# source_title        36
# content_text         0
# category          2578
# lang                 0
# dtype: int64

# %%
# counting each value under class column
new_df1['class'].value_counts()
# Out:
# False                          1181
# FALSE                          1085
# Misleading                      143
# Mostly false                     66
# MISLEADING                       53
# Mostly False                     43
# misleading                       36
# True                             34
# Partly false                     15
# Unproven                         10
# Mostly True                       8
# PARTLY FALSE                      8
# MOSTLY FALSE                      8
# No evidence                       8
# MOSTLY TRUE                       7
# (Org. doesn't apply rating)       7
# HALF TRUE                         6
# Labeled Satire                    5
# Two Pinocchios                    3
# Scam                              3
# Half True                         3
# Partly False                      3
# Not true                          2
# half true                         2
# PARTLY TRUE                       1
# Partially false                   1
# ...

# %%
# lowercasing the values in class column
new_df1['class'] = new_df1['class'].apply(lambda x: x.lower())
# Out:
# C:\Users\KRISHN~1\AppData\Local\Temp/ipykernel_10336/209449396.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df1['class'] = new_df1['class'].apply(lambda x: x.lower())

# %%
new_df1.head(10)
# Out:
#         verifiedby         country        class  \
# 2    FactCrescendo           India        false
# 5       VERA Files     Philippines   misleading
# 7        GhanaFact           Ghana  mostly true
# 8       PolitiFact   United States        false
# 9      AfricaCheck           Kenya        false
# 19       GhanaFact           Ghana        false
# 21             AFP   United States   misleading
# 24   FactCrescendo           India        false
# 27      PolitiFact   United States        false
# 28    Vishvas News           India        false
#
#                                                 title published_date  \
# 2    Chinese converting to Islam after realizing t...    2020/02/20
# 5    Captions on a reuploaded video about the U.S....    2020/05/09
# 7    Ghana has 307 ambulances with mobile ventilat...    2020/04/03
# 8    “Governor Andy Beshear has authorized Kentuck...    2020/04/29
# 9    Photo shows food being distributed to Rwandan...    2020/03/30
# ...

# %%
new_df1['class'].value_counts()
# Out:
# false                          2266
# misleading                      233
# mostly false                    117
# true                             34
# partly false                     26
# mostly true                      15
# half true                        11
# unproven                         10
# no evidence                       9
# (org. doesn't apply rating)       7
# labeled satire                    5
# two pinocchios                    3
# scam                              3
# not true                          2
# partly true                       2
# partially false                   1
# fake                              1
# pants on fire                     1
# partially correct                 1
# unlikely                          1
# collections                       1
# partially true                    1
# Name: class, dtype: int64

# %%
new_df1.columns
# Out:
# Index(['verifiedby', 'country', 'class', 'title', 'published_date', 'country1',
#        'country2', 'country3', 'country4', 'ref_source', 'source_title',
#        'content_text', 'category', 'lang'],
#       dtype='object')

# %%
# creating dataframe only with features required for classification
classification_dataframe = new_df1[['title', 'content_text', 'published_date', 'ref_source', 'class']]

# %%
classification_dataframe.head(10)
# Out:
#                                                 title  \
# 2    Chinese converting to Islam after realizing t...
# 5    Captions on a reuploaded video about the U.S....
# 7    Ghana has 307 ambulances with mobile ventilat...
# 8    “Governor Andy Beshear has authorized Kentuck...
# 9    Photo shows food being distributed to Rwandan...
# 19           Chewing raw onions can cure coronavirus.
# 21   Ads are selling masks protecting against COVI...
# 24   Komal Mishra, a staff nurse at a hospital in ...
# 27   “The mainstream media pretended there was a d...
# 28   China seeks court’s approval to kill 20,000 c...
#
#                                          content_text published_date  \
# 2   The fact behind every news!, Ever since the Wo...    2020/02/20
# 5   AUTHOR, VERA Files, DATE, May 08, 2020, SHARE,...    2020/05/09
# 7   Source: Dr Anthony Nsiah Asare, Verdict: Mostl...    2020/04/03
# 8   More Info, Trying to focus on school work at h...    2020/04/29
# ...

# %%
classification_dataframe['class'].value_counts()
# Out:
# false                          2266
# misleading                      233
# mostly false                    117
# true                             34
# partly false                     26
# mostly true                      15
# half true                        11
# unproven                         10
# no evidence                       9
# (org. doesn't apply rating)       7
# labeled satire                    5
# two pinocchios                    3
# scam                              3
# not true                          2
# partly true                       2
# partially false                   1
# fake                              1
# pants on fire                     1
# partially correct                 1
# unlikely                          1
# collections                       1
# partially true                    1
# Name: class, dtype: int64

# %%
# filtering rows and coloumns having true or false values under class column
cl_df = classification_dataframe.loc[classification_dataframe['class'].isin(['true', 'false'])]

# %%
cl_df.head(10)
# Out:
#                                                 title  \
# 2    Chinese converting to Islam after realizing t...
# 8    “Governor Andy Beshear has authorized Kentuck...
# 9    Photo shows food being distributed to Rwandan...
# 19           Chewing raw onions can cure coronavirus.
# 24   Komal Mishra, a staff nurse at a hospital in ...
# 27   “The mainstream media pretended there was a d...
# 28   China seeks court’s approval to kill 20,000 c...
# 30   A “Chinese spy team” working in a Canadian go...
# 32  Did Trump Tweet in 2009 That He Would ‘Never L...
# 34        Houseflies can transmit the COVID-19 virus.
#
#                                          content_text       published_date  \
# 2   The fact behind every news!, Ever since the Wo...          2020/02/20
# 8   More Info, Trying to focus on school work at h...          2020/04/29
# 9   A photo of hundreds of neat piles of bedding a...          2020/03/30
# ...

# %%
# checking for null values
cl_df.isnull().sum()
# Out:
# title             0
# content_text      0
# published_date    0
# ref_source        0
# class             0
# dtype: int64

# %%
cl_df['published_date'].value_counts()
# Out:
# 2020/03/24             52
# 2020/03/23             48
# 2020/03/25             46
# 2020/03/22             43
# 2020/03/19             41
#                        ..
# 2020-03-24 00:00:00     1
# 2020-03-27 00:00:00     1
# 2020-05-07 00:00:00     1
# 2020-04-26 00:00:00     1
# 2020-03-21 00:00:00     1
# Name: published_date, Length: 220, dtype: int64

# %%
# normalizing published_date feature to get same date format for all values
cl_df['published_date'] =  pd.to_datetime(cl_df['published_date']).dt.normalize()
# Out:
# C:\Users\KRISHN~1\AppData\Local\Temp/ipykernel_10336/3696343609.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_df['published_date'] =  pd.to_datetime(cl_df['published_date']).dt.normalize()

# %%
cl_df.head(10)
# Out:
#                                                 title  \
# 2    Chinese converting to Islam after realizing t...
# 8    “Governor Andy Beshear has authorized Kentuck...
# 9    Photo shows food being distributed to Rwandan...
# 19           Chewing raw onions can cure coronavirus.
# 24   Komal Mishra, a staff nurse at a hospital in ...
# 27   “The mainstream media pretended there was a d...
# 28   China seeks court’s approval to kill 20,000 c...
# 30   A “Chinese spy team” working in a Canadian go...
# 32  Did Trump Tweet in 2009 That He Would ‘Never L...
# 34        Houseflies can transmit the COVID-19 virus.
#
#                                          content_text published_date  \
# 2   The fact behind every news!, Ever since the Wo...     2020-02-20
# 8   More Info, Trying to focus on school work at h...     2020-04-29
# 9   A photo of hundreds of neat piles of bedding a...     2020-03-30
# 19  Source: Unknown, Verdict: False, Researched by...     2020-05-29
# ...

# %%
cl_df.head(10)
# Out:
#                                                 title  \
# 2    Chinese converting to Islam after realizing t...
# 8    “Governor Andy Beshear has authorized Kentuck...
# 9    Photo shows food being distributed to Rwandan...
# 19           Chewing raw onions can cure coronavirus.
# 24   Komal Mishra, a staff nurse at a hospital in ...
# 27   “The mainstream media pretended there was a d...
# 28   China seeks court’s approval to kill 20,000 c...
# 30   A “Chinese spy team” working in a Canadian go...
# 32  Did Trump Tweet in 2009 That He Would ‘Never L...
# 34        Houseflies can transmit the COVID-19 virus.
#
#                                          content_text published_date  \
# 2   The fact behind every news!, Ever since the Wo...     2020-02-20
# 8   More Info, Trying to focus on school work at h...     2020-04-29
# 9   A photo of hundreds of neat piles of bedding a...     2020-03-30
# 19  Source: Unknown, Verdict: False, Researched by...     2020-05-29
# ...

# %%
cl_df.reset_index(inplace = True)

# %%
cl_df.head(10)
# Out:
#    index                                              title  \
# 0      2   Chinese converting to Islam after realizing t...
# 1      8   “Governor Andy Beshear has authorized Kentuck...
# 2      9   Photo shows food being distributed to Rwandan...
# 3     19           Chewing raw onions can cure coronavirus.
# 4     24   Komal Mishra, a staff nurse at a hospital in ...
# 5     27   “The mainstream media pretended there was a d...
# 6     28   China seeks court’s approval to kill 20,000 c...
# 7     30   A “Chinese spy team” working in a Canadian go...
# 8     32  Did Trump Tweet in 2009 That He Would ‘Never L...
# 9     34        Houseflies can transmit the COVID-19 virus.
#
#                                         content_text published_date  \
# 0  The fact behind every news!, Ever since the Wo...     2020-02-20
# 1  More Info, Trying to focus on school work at h...     2020-04-29
# 2  A photo of hundreds of neat piles of bedding a...     2020-03-30
# ...

# %%
cl_df.drop('index', axis = 1, inplace = True)
# Out:
# C:\Users\Krishnaji Shukla\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
cl_df.head(10)
# Out:
#                                                title  \
# 0   Chinese converting to Islam after realizing t...
# 1   “Governor Andy Beshear has authorized Kentuck...
# 2   Photo shows food being distributed to Rwandan...
# 3           Chewing raw onions can cure coronavirus.
# 4   Komal Mishra, a staff nurse at a hospital in ...
# 5   “The mainstream media pretended there was a d...
# 6   China seeks court’s approval to kill 20,000 c...
# 7   A “Chinese spy team” working in a Canadian go...
# 8  Did Trump Tweet in 2009 That He Would ‘Never L...
# 9        Houseflies can transmit the COVID-19 virus.
#
#                                         content_text published_date  \
# 0  The fact behind every news!, Ever since the Wo...     2020-02-20
# 1  More Info, Trying to focus on school work at h...     2020-04-29
# 2  A photo of hundreds of neat piles of bedding a...     2020-03-30
# 3  Source: Unknown, Verdict: False, Researched by...     2020-05-29
# ...

# %%
cl_df['class'].value_counts()
# Out:
# false    2266
# true       34
# Name: class, dtype: int64

# %%
cl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2300 entries, 0 to 2299
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           2300 non-null   object
#  1   content_text    2300 non-null   object
#  2   published_date  2300 non-null   datetime64[ns]
#  3   ref_source      2300 non-null   object
#  4   class           2300 non-null   object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 90.0+ KB

# %%
cl_df.shape
# Out:
# (2300, 5)

# %%
# converting true and false values to numbers, true = 1 and false = 0 and creating column class1 with these values
cl_df['class1'] = cl_df['class'].apply(lambda x:1 if x == 'true' else 0)
# Out:
# C:\Users\KRISHN~1\AppData\Local\Temp/ipykernel_10336/245737668.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_df['class1'] = cl_df['class'].apply(lambda x:1 if x == 'true' else 0)

# %%
cl_df.head(10)
# Out:
#                                                title  \
# 0   Chinese converting to Islam after realizing t...
# 1   “Governor Andy Beshear has authorized Kentuck...
# 2   Photo shows food being distributed to Rwandan...
# 3           Chewing raw onions can cure coronavirus.
# 4   Komal Mishra, a staff nurse at a hospital in ...
# 5   “The mainstream media pretended there was a d...
# 6   China seeks court’s approval to kill 20,000 c...
# 7   A “Chinese spy team” working in a Canadian go...
# 8  Did Trump Tweet in 2009 That He Would ‘Never L...
# 9        Houseflies can transmit the COVID-19 virus.
#
#                                         content_text published_date  \
# 0  The fact behind every news!, Ever since the Wo...     2020-02-20
# 1  More Info, Trying to focus on school work at h...     2020-04-29
# 2  A photo of hundreds of neat piles of bedding a...     2020-03-30
# 3  Source: Unknown, Verdict: False, Researched by...     2020-05-29
# ...

# %%
# dropping class column
cl_df.drop('class', axis = 1, inplace = True)
# Out:
# C:\Users\Krishnaji Shukla\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
cl_df.head(10)
# Out:
#                                                title  \
# 0   Chinese converting to Islam after realizing t...
# 1   “Governor Andy Beshear has authorized Kentuck...
# 2   Photo shows food being distributed to Rwandan...
# 3           Chewing raw onions can cure coronavirus.
# 4   Komal Mishra, a staff nurse at a hospital in ...
# 5   “The mainstream media pretended there was a d...
# 6   China seeks court’s approval to kill 20,000 c...
# 7   A “Chinese spy team” working in a Canadian go...
# 8  Did Trump Tweet in 2009 That He Would ‘Never L...
# 9        Houseflies can transmit the COVID-19 virus.
#
#                                         content_text published_date  \
# 0  The fact behind every news!, Ever since the Wo...     2020-02-20
# 1  More Info, Trying to focus on school work at h...     2020-04-29
# 2  A photo of hundreds of neat piles of bedding a...     2020-03-30
# 3  Source: Unknown, Verdict: False, Researched by...     2020-05-29
# ...

# %%
data = cl_df.sample(frac=1)
data.reset_index(inplace=True)
data.drop(["index"], axis=1, inplace=True)

# %%
# creating count plot for the class1 colulmn to visualize category count
sns.countplot(data=data,
              x='class1',
              order=data['class1'].value_counts().index)
# Out:
# <AxesSubplot:xlabel='class1', ylabel='count'>

# %%
# importing required  nlp libraries for text preprocessing
from tqdm import tqdm
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Krishnaji
# [nltk_data]     Shukla\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Krishnaji
# [nltk_data]     Shukla\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Krishnaji
# [nltk_data]     Shukla\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
# removing stopwords and lowercasing the text
def preprocess_text(text_data):
    preprocessed_text = []
      
    for sentence in tqdm(text_data):
        sentence = re.sub(r'[^\w\s]', '', sentence)
        preprocessed_text.append(' '.join(token.lower()
                                  for token in str(sentence).split()
                                  if token not in stopwords.words('english')))
  
    return preprocessed_text

# %%
preprocessed_review = preprocess_text(data['content_text'].values)
data['content_text'] = preprocessed_review
# Out:
# 100%|██████████| 2300/2300 [04:30<00:00,  8.51it/s]

# %%
# plotting top 20 most frequent words
from sklearn.feature_extraction.text import CountVectorizer
  
  
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx])
                  for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1],
                        reverse=True)
    return words_freq[:n]
  
  
common_words = get_top_n_words(data['content_text'], 20)
df1 = pd.DataFrame(common_words, columns=['Review', 'count'])
  
df1.groupby('Review').sum()['count'].sort_values(ascending=False).plot(
    kind='bar',
    figsize=(10, 6),
    xlabel="Top Words",
    ylabel="Count",
    title="Bar Chart of Top Words Frequency"
)
# Out:
# <AxesSubplot:title={'center':'Bar Chart of Top Words Frequency'}, xlabel='Top Words', ylabel='Count'>

# %%
# Splitting the dataset in train and test
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
  
x_train, x_test, y_train, y_test = train_test_split(data['content_text'], 
                                                    data['class1'], 
                                                    test_size=0.25)

# %%
# conveting data in vectores using Tfidf Vectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
  
vectorization = TfidfVectorizer()
x_train = vectorization.fit_transform(x_train)
x_test = vectorization.transform(x_test)

# %% [markdown]
# ## SMOTE Analysis for Creating Balanced Class

# %%
from imblearn.over_sampling import SMOTE
smt = SMOTE()
x_train_sm, y_train_sm = smt.fit_resample(x_train, y_train)

# %%
from imblearn.over_sampling import SMOTE
smt = SMOTE()
x_test_sm, y_test_sm = smt.fit_resample(x_test, y_test)

# %% [markdown]
# ## Modeling

# %% [markdown]
# ## Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
  
model = LogisticRegression()
model.fit(x_train_sm, y_train_sm)
  
# testing the model
print(accuracy_score(y_train_sm, model.predict(x_train_sm)))
print(accuracy_score(y_test_sm, model.predict(x_test_sm)))
# Out:
# 0.9935408103347034
# 0.9600355239786856

# %% [markdown]
# ## Decision Tree Classification Model

# %%
from sklearn.tree import DecisionTreeClassifier
  
model = DecisionTreeClassifier()
model.fit(x_train_sm, y_train_sm)
  
# testing the model
print(accuracy_score(y_train_sm, model.predict(x_train_sm)))
print(accuracy_score(y_test_sm, model.predict(x_test_sm)))
# Out:
# 1.0
# 0.8063943161634103

# %% [markdown]
# ## Random Forest Classification Model

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators = 100)  
clf.fit(x_train_sm, y_train_sm)
print(accuracy_score(y_train_sm, clf.predict(x_train_sm)))
print(accuracy_score(y_test_sm, clf.predict(x_test_sm)))
# Out:
# 1.0
# 0.9476021314387212

# %% [markdown]
# ## Evaluation

# %%
# importing the required classification metrics
from sklearn import metrics
cm = metrics.confusion_matrix(y_test_sm, model.predict(x_test_sm))
  
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix=cm,
                                            display_labels=[False, True])
  
cm_display.plot()
plt.show()

# %%
# importing the classification report
from sklearn.metrics import classification_report
print(classification_report(y_train_sm, clf.predict(x_train_sm)))
print(classification_report(y_test_sm, clf.predict(x_test_sm)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1703
#            1       1.00      1.00      1.00      1703
#
#     accuracy                           1.00      3406
#    macro avg       1.00      1.00      1.00      3406
# weighted avg       1.00      1.00      1.00      3406
#
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       563
#            1       0.99      0.90      0.95       563
#
#     accuracy                           0.95      1126
#    macro avg       0.95      0.95      0.95      1126
# weighted avg       0.95      0.95      0.95      1126
